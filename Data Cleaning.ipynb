# %%
import pandas as pd
import numpy as np

# %%
bank = pd.read_csv('train.csv', sep=';')

# %%
bank.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %% [markdown]
# PLAN
#
# Saya drop duration karena sangat berpengaruh terhadap target hingga terkesan bias terhadap 0.<br>
# poutcome dihapus karena outknownnya ada lebih dari 80%<br>
# unknown pada job dihapus, unknown lainnya bikin ke mode.
#
# Drop:
# - poutcome
# - duration

# %%
bank.y = np.where(bank['y'] == 'yes', 1, 0)

# %%
bank1 = bank.copy()
bank1 = bank1.drop(bank1[bank1['job'] == 'unknown'].index)
bank1 = bank1.drop(['poutcome', 'duration'], axis=1)

# %%
bank1
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 5       35    management   married   tertiary      no      231     yes   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
bank.shape
# Out:
# (45211, 17)

# %%
bank.job.unique()
# Out:
# array(['management', 'technician', 'entrepreneur', 'blue-collar',
#        'unknown', 'retired', 'admin.', 'services', 'self-employed',
#        'unemployed', 'housemaid', 'student'], dtype=object)

# %%
bank1.to_csv(r'E:\Putra\Final Project\Model\bank_clean_out.csv', index=False)

# %%
bank_clean_out = pd.read_csv('bank_clean_out.csv')

# %%
bank_clean_out
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       35    management   married   tertiary      no      231     yes   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 44918   51    technician   married   tertiary      no      825      no   no
# 44919   71       retired  divorced    primary      no     1729      no   no
# 44920   72       retired   married  secondary      no     5715      no   no
# 44921   57   blue-collar   married  secondary      no      668      no   no
# 44922   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...
